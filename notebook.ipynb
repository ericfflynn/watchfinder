# %% [markdown]
# # Web Scraping Watch Data

# %% [markdown]
# 1. Prepare Virtual Environment
# -
# 2. Generate Scrapy Project
# - scrapy start project scrapy_project ./watchfinder
# 3. Generate Spider
# - cd scrapy_project
# - scrapy genspider
# 4. Update Settings
# 5. Program Crawler
# 6. Crawl Data and Store Results

# %% [markdown]
# # Results

# %%
import json
import pandas as pd

with open("./scrapy_project/outputs/output.json") as f:
    df = pd.DataFrame(json.load(f))

print(len(df), " Records Scraped")
print(list(df.columns))
df.describe()
# Out:
# 61  Records Scraped
# ['Listing code', 'Brand', 'Model', 'Reference number', 'Movement', 'Case material', 'Bracelet material', 'Year of production', 'Condition', 'Scope of delivery', 'Gender', 'Location', 'Price', 'Availability', 'Caliber/movement', 'Base caliber', 'Power reserve', 'Number of jewels', 'Case diameter', 'Water resistance', 'Bezel material', 'Crystal', 'Dial', 'Dial numerals', 'Bracelet color', 'Clasp', 'Clasp material', 'Dealer product code', 'Frequency', 'Thickness', 'Lug width', 'Date']
#        Listing code  Brand        Model Reference number   Movement  \
# count            61     61           61               60         61
# unique           61      1            6               26          1
# top          JH1893  Rolex  Datejust 41           126334  Automatic
# freq              1     61           30               10         61
#
#        Case material Bracelet material Year of production  \
# count             61                61                 61
# ...
